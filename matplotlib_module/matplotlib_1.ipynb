# %% [markdown]
# ### lecture 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# #### functional method of plotting

# %%
plt.plot(x,y,'red')

# %%
plt.plot(x,y)
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'red')

plt.subplot(1,2,2)
plt.plot(y,x,'blue')

# %% [markdown]
# #### object oriented method of plotting

# %%
fig = plt.figure() # figure object as a blank canvas

axes = fig.add_axes([0.1,0.1,0.8,0.8]) # axes

axes.plot(x,y)
axes.set_xlabel('x label')
axes.set_ylabel('y label')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) 
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) # left, bottom, width and height with respect to the empty canva

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) 
axes2 = fig.add_axes([0.4,0.15,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) 
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('larger plot')

axes2.plot(y,x)
axes2.set_title('smaller plot')
# Out:
# Text(0.5, 1.0, 'smaller plot')

# %% [markdown]
# ### lecture 2

# %%
fig,axes = plt.subplots(nrows=3, ncols=2)

# axes.plot(x,y)
plt.tight_layout() # fix the overlap of subplots

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

for current_ax in axes: # axes object is iterable 
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)
axes[0].set_title('first plot')

axes[1].plot(y,x)
axes[1].set_title('second plot')
# Out:
# Text(0.5, 1.0, 'second plot')

# %% [markdown]
# #### figure size and DPI

# %%
# tuple is the width and height in inches and dpi are the pixels for inch
fig = plt.figure(figsize=(3,2), dpi=100) 

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,2), dpi=100) 

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2), dpi=100) 

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout() # not overlapping subplots

# %% [markdown]
# #### how to save a figure

# %%
fig

# %%
fig.savefig('my_picture.png')

# %% [markdown]
# #### legend

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

# label is the string that the legend function is able to reference 
ax.plot(x,x**2, label='x squared') 
ax.plot(x,x**3, label = 'x cubed')

# check if there is a label, that will be returned in the plot
ax.legend(loc='best') # best location for our legend

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

# label is the string that the legend function is able to reference 
ax.plot(x,x**2, label='x squared') 
ax.plot(x,x**3, label = 'x cubed')

# check if there is a label, that will be returned in the plot
ax.legend(loc=(0.1,0.1))

# %% [markdown]
# ### lecture 3

# %% [markdown]
# #### customize plots - setting colors

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='#FF8C00') # more custom color

# %% [markdown]
# #### line width

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# twenty time the thickness of the original line
ax.plot(x,y, color='green', linewidth = 20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# alpha regulates the transparency of the line
ax.plot(x,y, color='green', linewidth = 20, alpha=0.5)

# %% [markdown]
# #### line style

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green', lw = 3, linestyle = '-.')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green', lw = 3, linestyle = ':')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green', lw = 3, ls = '--')

# %% [markdown]
# #### markers

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# 'marker' markes where the 11 points of x are with respect to y
ax.plot(x,y, color='green', lw = 3, ls = '--', marker='o', markersize = 10,
        markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='blue')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green', lw = 3, ls = '--', marker='+', markersize = 20)

# %% [markdown]
# #### examples

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range")
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %% [markdown]
# #### plot range

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# 'marker' markes where the 11 points of x are with respect to y
ax.plot(x,y, color='green', lw = 2, ls = '--')

# set the lower bound and upper bound of the x axis
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# #### special plot types

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([12.,  7., 21.,  9.,  8.,  9., 11.,  8.,  5., 10.]),
#  array([  3., 102., 201., 300., 399., 498., 597., 696., 795., 894., 993.]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True)
plt.show()
